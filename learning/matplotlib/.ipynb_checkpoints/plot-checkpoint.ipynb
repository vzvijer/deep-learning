# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = [x for x in range(10)]
Y = [x if x % 2 == 0 else x - 1 for x in X]

# %%
plt.plot(X, Y)
plt.show()

# %%
X = np.arange(0, 10, 0.1)
Y = np.sin(X)

# %%
plt.plot(X, Y)
plt.show()
