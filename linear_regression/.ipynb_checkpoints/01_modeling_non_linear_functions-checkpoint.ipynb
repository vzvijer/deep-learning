# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %matplotlib inline

# %%
x = np.array(range(1001)) / 100 - 5
y = np.sin(2 * x) + np.exp(0.3 * x)

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## One feature, one dense layer

# %%
X = x
T = y

use_activation = True

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=(1,), activation='relu' if use_activation else None),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(loss='mse', optimizer='adam')

# %%
model.fit(X, T, epochs=100, verbose=0)

# %%
Y = model.predict(X)

# %%
plt.plot(X, T, c='blue')
plt.plot(X, Y, c='red')
plt.show()

# %% [markdown]
# ## Two features, one dense layer

# %%
X1 = x
X2 = X1.T*X1
X = np.array([X1, X2]).T
T = y

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=(2,), activation='relu'),
    tf.keras.layers.Dense(1)
])
model.compile(loss='mse', optimizer='adam')
model.fit(X, T, epochs=100, verbose=0)
Y = model.predict(X)

# %%
plt.plot(x, T, c='blue')
plt.plot(x, Y, c='red')
plt.show()

# %% [markdown]
# ## Three features, one dense layer

# %%
X1 = x
X2 = X1.T * X1 # x^2
X3 = X2.T * X1 # x^3
X = np.array([X1, X2, X3]).T
T = y

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=(3,), activation='relu'),
    tf.keras.layers.Dense(1)
])
model.compile(loss='mse', optimizer='adam')
model.fit(X, T, epochs=100, verbose=0)
Y = model.predict(X)

# %%
plt.plot(x, T, c='blue')
plt.plot(x, Y, c='red')
plt.show()

# %% [markdown]
# ## One feature, two dense layers

# %%
X = x
T = y

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=(1,), activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)
])
model.compile(loss='mse', optimizer='adam')
model.fit(X, T, epochs=100, verbose=0)
Y = model.predict(X)

# %%
plt.plot(x, T, c='blue')
plt.plot(x, Y, c='red')
plt.show()

# %% [markdown]
# ## Two features, two dense layers

# %%
X1 = x
X2 = X1.T*X1
X = np.array([X1, X2]).T
T = y

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=(2,), activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)
])
model.compile(loss='mse', optimizer='adam')
model.fit(X, T, epochs=100, verbose=0)
Y = model.predict(X)

# %%
plt.plot(x, T, c='blue')
plt.plot(x, Y, c='red')
plt.show()
